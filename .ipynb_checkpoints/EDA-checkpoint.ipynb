# %%
import pandas as pd
import seaborn as sns
import altair as alt
from summarytools import dfSummary

# %%
og_obesity = pd.read_csv("ObesityDataSet.csv")
train_dlm = pd.read_csv("train_dlm.csv")
test_data = pd.read_csv("test.csv")

# %%
dfSummary(og_obesity, is_collapsible=True)
dfSummary(train_dlm, is_collapsible=True)
dfSummary(test_data, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-3493" onclick = "coll_toggle_3493()">Show Summary - test_data</button>
#     <div class="st-content" id="cont-3493">
#       <style type="text/css">
# #T_80277 thead>tr>th {
#   text-align: left;
# }
# #T_80277_row0_col0, #T_80277_row1_col0, #T_80277_row2_col0, #T_80277_row3_col0, #T_80277_row4_col0, #T_80277_row5_col0, #T_80277_row6_col0, #T_80277_row7_col0, #T_80277_row8_col0, #T_80277_row9_col0, #T_80277_row10_col0, #T_80277_row11_col0, #T_80277_row12_col0, #T_80277_row13_col0, #T_80277_row14_col0, #T_80277_row15_col0, #T_80277_row16_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_80277_row0_col1, #T_80277_row1_col1, #T_80277_row2_col1, #T_80277_row3_col1, #T_80277_row4_col1, #T_80277_row5_col1, #T_80277_row6_col1, #T_80277_row7_col1, #T_80277_row8_col1, #T_80277_row9_col1, #T_80277_row10_col1, #T_80277_row11_col1, #T_80277_row12_col1, #T_80277_row13_col1, #T_80277_row14_col1, #T_80277_row15_col1, #T_80277_row16_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_80277_row0_col2, #T_80277_row1_col2, #T_80277_row2_col2, #T_80277_row3_col2, #T_80277_row4_col2, #T_80277_row5_col2, #T_80277_row6_col2, #T_80277_row7_col2, #T_80277_row8_col2, #T_80277_row9_col2, #T_80277_row10_col2, #T_80277_row11_col2, #T_80277_row12_col2, #T_80277_row13_col2, #T_80277_row14_col2, #T_80277_row15_col2, #T_80277_row16_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_80277_row0_col3, #T_80277_row1_col3, #T_80277_row2_col3, #T_80277_row3_col3, #T_80277_row4_col3, #T_80277_row5_col3, #T_80277_row6_col3, #T_80277_row7_col3, #T_80277_row8_col3, #T_80277_row9_col3, #T_80277_row10_col3, #T_80277_row11_col3, #T_80277_row12_col3, #T_80277_row13_col3, #T_80277_row14_col3, #T_80277_row15_col3, #T_80277_row16_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_80277_row0_col4, #T_80277_row1_col4, #T_80277_row2_col4, #T_80277_row3_col4, #T_80277_row4_col4, #T_80277_row5_col4, #T_80277_row6_col4, #T_80277_row7_col4, #T_80277_row8_col4, #T_80277_row9_col4, #T_80277_row10_col4, #T_80277_row11_col4, #T_80277_row12_col4, #T_80277_row13_col4, #T_80277_row14_col4, #T_80277_row15_col4, #T_80277_row16_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_80277_row0_col5, #T_80277_row1_col5, #T_80277_row2_col5, #T_80277_row3_col5, #T_80277_row4_col5, #T_80277_row5_col5, #T_80277_row6_col5, #T_80277_row7_col5, #T_80277_row8_col5, #T_80277_row9_col5, #T_80277_row10_col5, #T_80277_row11_col5, #T_80277_row12_col5, #T_80277_row13_col5, #T_80277_row14_col5, #T_80277_row15_col5, #T_80277_row16_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_80277">
#   <caption><strong>Data Frame Summary</strong><br>test_data<br>Dimensions: 13,840 x 17<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_80277_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_80277_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_80277_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_80277_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_80277_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_80277_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_80277_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_80277_row0_col1" class="data row0 col1" ><strong>id</strong><br>[int64]</td>
#       <td id="T_80277_row0_col2" class="data row0 col2" >Mean (sd) : 27677.5 (3995.4)<br>min < med < max:<br>20758.0 < 27677.5 < 34597.0<br>IQR (CV) : 6919.5 (6.9)</td>
#       <td id="T_80277_row0_col3" class="data row0 col3" >13,840 distinct values</td>
#       <td id="T_80277_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_80277_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_80277_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_80277_row1_col1" class="data row1 col1" ><strong>Gender</strong><br>[object]</td>
#       <td id="T_80277_row1_col2" class="data row1 col2" >1. Female<br>2. Male</td>
#       <td id="T_80277_row1_col3" class="data row1 col3" >6,965 (50.3%)<br>6,875 (49.7%)</td>
#       <td id="T_80277_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_80277_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_80277_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_80277_row2_col1" class="data row2 col1" ><strong>Age</strong><br>[float64]</td>
#       <td id="T_80277_row2_col2" class="data row2 col2" >Mean (sd) : 24.0 (5.8)<br>min < med < max:<br>14.0 < 22.9 < 61.0<br>IQR (CV) : 6.0 (4.1)</td>
#       <td id="T_80277_row2_col3" class="data row2 col3" >1,539 distinct values</td>
#       <td id="T_80277_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_80277_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_80277_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_80277_row3_col1" class="data row3 col1" ><strong>Height</strong><br>[float64]</td>
#       <td id="T_80277_row3_col2" class="data row3 col2" >Mean (sd) : 1.7 (0.1)<br>min < med < max:<br>1.4 < 1.7 < 2.0<br>IQR (CV) : 0.1 (19.1)</td>
#       <td id="T_80277_row3_col3" class="data row3 col3" >1,739 distinct values</td>
#       <td id="T_80277_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_80277_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_80277_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_80277_row4_col1" class="data row4 col1" ><strong>Weight</strong><br>[float64]</td>
#       <td id="T_80277_row4_col2" class="data row4 col2" >Mean (sd) : 87.4 (26.1)<br>min < med < max:<br>39.0 < 84.0 < 165.1<br>IQR (CV) : 46.2 (3.3)</td>
#       <td id="T_80277_row4_col3" class="data row4 col3" >1,798 distinct values</td>
#       <td id="T_80277_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_80277_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_80277_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_80277_row5_col1" class="data row5 col1" ><strong>family_history_with_overweight</strong><br>[object]</td>
#       <td id="T_80277_row5_col2" class="data row5 col2" >1. yes<br>2. no</td>
#       <td id="T_80277_row5_col3" class="data row5 col3" >11,384 (82.3%)<br>2,456 (17.7%)</td>
#       <td id="T_80277_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_80277_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_80277_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_80277_row6_col1" class="data row6 col1" ><strong>FAVC</strong><br>[object]</td>
#       <td id="T_80277_row6_col2" class="data row6 col2" >1. yes<br>2. no</td>
#       <td id="T_80277_row6_col3" class="data row6 col3" >12,583 (90.9%)<br>1,257 (9.1%)</td>
#       <td id="T_80277_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_80277_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_80277_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_80277_row7_col1" class="data row7 col1" ><strong>FCVC</strong><br>[float64]</td>
#       <td id="T_80277_row7_col2" class="data row7 col2" >Mean (sd) : 2.4 (0.5)<br>min < med < max:<br>1.0 < 2.4 < 3.0<br>IQR (CV) : 1.0 (4.6)</td>
#       <td id="T_80277_row7_col3" class="data row7 col3" >828 distinct values</td>
#       <td id="
